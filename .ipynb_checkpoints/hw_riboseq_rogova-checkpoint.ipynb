# %% [markdown]
# ## Биоинформатика для высокопроизводительного секвенирования
# ## Домашнее задание № 7 "Рибосомный профайлинг"
# #### Студент: Рогова Полина
# #### Группа: мАДБМ19

# %%
options(warn = -1)
library('ggplot2')
library('dplyr')
library('tidyr')
library('edgeR')
library('EnhancedVolcano')
library('ape')
library('png')
if (!require(devtools)) install.packages("devtools")
devtools::install_github("yanlinlin82/ggvenn")
library("ggvenn")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: limma
#
# Loading required package: ggrepel

# %% [markdown]
# ##### Задание 1. Определение дифференциальной экспрессии

# %% [markdown]
# В папке курса на Google Drive хранится файл 0​ 1. RiboSeq_RNASeq_HCC_counts.tsv,​в котором содержится матрица каунтов результатов Ribo-Seq и RNA-Seq экспериментов больных гепатоцеллюлярной карциномой. Матрица каунтов была получена стандартным воркфлоу STAR. На каждого пациента приходится 4 столбца в таблице (RNA-Seq нормы и опухоли, Ribo-Seq нормы и опухоли), записанные в виде ​sample_number-tissue_type-experiment.​

# %%
data <- read.csv('/users/vraip/Anaconda/ngs/hw_riboseq/01. RiboSeq_RNASeq_HCC_counts.tsv', sep = '\t')
apply(data, 2, function(x) { table(is.na(x))}) # все na в столбце LC509.tumor.RNA
# т.к. не хочется удалять более 2,5к строк, и весь столбец, наверное, некорректно в данном случае убирать,
# заменим na на 0
data[which(is.na(data$LC509.tumor.RNA)), ]$LC509.tumor.RNA <- 0
#head(data)
# Out:
# $geneID
#
# FALSE
# 18945
#
# $geneSymbol
#
# FALSE
# 18945
#
# $LC001.normal.RPF
#
# FALSE
# 18945
#
# $LC001.tumor.RPF
#
# FALSE
# 18945
#
# $LC001.normal.RNA
#
# FALSE
# 18945
#
# $LC001.tumor.RNA
#
# FALSE
# 18945
#
# $LC033.normal.RPF
#
# FALSE
# 18945
#
# $LC033.tumor.RPF
#
# FALSE
# 18945
#
# $LC033.normal.RNA
#
# FALSE
# 18945
#
# $LC033.tumor.RNA
#
# FALSE
# 18945
#
# $LC034.normal.RPF
#
# FALSE
# 18945
#
# $LC034.tumor.RPF
#
# FALSE
# 18945
#
# $LC034.normal.RNA
#
# FALSE
# 18945
#
# $LC034.tumor.RNA
#
# FALSE
# 18945
#
# $LC501.normal.RPF
#
# FALSE
# 18945
#
# $LC501.tumor.RPF
#
# FALSE
# 18945
#
# $LC501.normal.RNA
#
# FALSE
# 18945
#
# $LC501.tumor.RNA
#
# FALSE
# 18945
#
# $LC502.normal.RPF
#
# FALSE
# 18945
#
# $LC502.tumor.RPF
#
# FALSE
# 18945
#
# $LC502.normal.RNA
#
# FALSE
# 18945
#
# $LC502.tumor.RNA
#
# FALSE
# 18945
#
# $LC505.normal.RPF
#
# FALSE
# 18945
#
# $LC505.tumor.RPF
#
# FALSE
# 18945
#
# $LC505.normal.RNA
#
# FALSE
# 18945
#
# $LC505.tumor.RNA
#
# FALSE
# 18945
#
# $LC506.normal.RPF
#
# FALSE
# 18945
#
# $LC506.tumor.RPF
#
# FALSE
# 18945
#
# $LC506.normal.RNA
#
# FALSE
# 18945
#
# $LC506.tumor.RNA
#
# FALSE
# 18945
#
# $LC507.normal.RPF
#
# FALSE
# 18945
#
# $LC507.tumor.RPF
#
# FALSE
# 18945
#
# $LC507.normal.RNA
#
# FALSE
# 18945
#
# $LC507.tumor.RNA
#
# FALSE
# 18945
#
# $LC508.normal.RPF
#
# FALSE
# 18945
#
# $LC508.tumor.RPF
#
# FALSE
# 18945
#
# $LC508.normal.RNA
#
# FALSE
# 18945
#
# $LC508.tumor.RNA
#
# FALSE
# 18945
#
# $LC509.normal.RPF
#
# FALSE
# 18945
#
# $LC509.tumor.RPF
#
# FALSE
# 18945
#
# $LC509.normal.RNA
#
# FALSE
# 18945
#
# $LC509.tumor.RNA
#
# FALSE  TRUE
# 16257  2688

# %%
# нормируем каунты
data_norm <- data.frame(apply(data[,3:ncol(data)], 2, function(x) {
  s <- sum(x)
  x / s * 10**6
}))
row.names(data_norm) <- data$geneID
head(data_norm)
# Out:
#                    LC001.normal.RPF LC001.tumor.RPF LC001.normal.RNA
# ENSG00000000003.14  0.000000         0.000000       90.600227
# ENSG00000000005.5   0.000000         0.000000        0.000000
# ENSG00000000419.12 29.925912        56.140516       19.832885
# ENSG00000000457.13 11.578478        28.422604       13.522422
# ENSG00000000460.16  1.425043        10.100595        4.056727
# ENSG00000000938.12  0.000000         1.409385        4.282100
#                    LC001.tumor.RNA LC033.normal.RPF LC033.tumor.RPF
# ENSG00000000003.14 179.8681585      0.000000         0.000000
# ENSG00000000005.5    0.2060345      0.000000         0.000000
# ENSG00000000419.12  38.5284601     23.885265        49.163025
# ENSG00000000457.13  21.8396619      7.542715        18.254153
# ENSG00000000460.16  14.4224182      3.352318         8.511139
# ENSG00000000938.12   1.8543109      2.933278         1.455853
#                    LC033.normal.RNA LC033.tumor.RNA LC034.normal.RPF
# ENSG00000000003.14 80.378639        290.386891       0.000000
# ENSG00000000005.5   0.000000          0.178480       0.000000
# ENSG00000000419.12 17.624552         35.874471      26.133408
# ENSG00000000457.13 18.692707         27.842873      10.453363
# ENSG00000000460.16  1.068155         11.244237       3.538061
# ENSG00000000938.12 16.289359          4.283519       1.206157
#                    LC034.tumor.RPF ⋯ LC507.normal.RNA LC507.tumor.RNA
# ENSG00000000003.14  0.000000       ⋯ 45.65337         88.660635
# ENSG00000000005.5   0.000000       ⋯  0.00000          0.000000
# ENSG00000000419.12 34.374579       ⋯ 19.26656         32.980980
# ENSG00000000457.13 22.328787       ⋯ 26.59623         34.145015
# ENSG00000000460.16  4.113198       ⋯ 25.96797         84.780519
# ENSG00000000938.12 18.215589       ⋯ 19.68540          2.522075
#                    LC508.normal.RPF LC508.tumor.RPF LC508.normal.RNA
# ENSG00000000003.14  0.0000000        0.000000       46.778833
# ENSG00000000005.5   0.2050456        0.000000        0.000000
# ENSG00000000419.12 22.3499656       51.647819       14.033650
# ENSG00000000457.13 13.7380523       25.462230       12.864179
# ENSG00000000003.14  0.000000        0.0000000        0.000000
# ENSG00000000005.5   0.000000        0.2050456        0.000000
# ENSG00000000419.12 65.279232       22.3499656       51.647819
# ENSG00000000457.13 26.362767       13.7380523       25.462230
# ENSG00000000460.16 56.491643        1.4353189       24.160184
# ENSG00000000938.12  0.251074        0.6151367        1.302046
#                    LC509.normal.RPF LC509.tumor.RPF
# ENSG00000000003.14  0.000000         0.000000
# ENSG00000000005.5   0.000000         0.000000
# ENSG00000000419.12 27.386761        32.582707
# ENSG00000000457.13 12.430870        18.833935
# ENSG00000000460.16  1.165394        11.488700
# ENSG00000000938.12  1.359626         1.883393

# %% [markdown]
# 1. Для каждого гена найдите коэффициент корреляции числа каунтов между экспериментами RNA-Seq и Ribo-Seq. Какую корреляцию вы выберете — Пирсона или Спирмена? Обратите внимание, что перед вами не нормированные каунты.

# %%
cors <- sapply(rownames(expr_RNA), function(x) {
    cor(x = as.numeric(expr_RNA[x,]), y = as.numeric(expr_RPF[x,]), method = "spearman")
})

# %%
cors <- data.frame(cc = cors)
cors['geneSymbol'] <- data$geneSymbol[rownames(cors) == data$geneID]
str(cors)
head(cors)
# Out:
# 'data.frame':	18945 obs. of  2 variables:
#  $ cc        : num  NA -0.139 0.824 0.6 0.765 ...
#  $ geneSymbol: chr  "TSPAN6" "TNMD" "DPM1" "SCYL3" ...
#                    cc         geneSymbol
# ENSG00000000003.14         NA TSPAN6
# ENSG00000000005.5  -0.1392888 TNMD
# ENSG00000000419.12  0.8240602 DPM1
# ENSG00000000457.13  0.6000000 SCYL3
# ENSG00000000460.16  0.7654135 C1orf112
# ENSG00000000938.12  0.4753667 FGR

# %%
cors <- cors %>% drop_na()
str(cors)
# Out:
# 'data.frame':	16859 obs. of  2 variables:
#  $ cc        : num  -0.139 0.824 0.6 0.765 0.475 ...
#  $ geneSymbol: chr  "TNMD" "DPM1" "SCYL3" "C1orf112" ...

# %% [markdown]
# 2. Постройте гистограмму распределения этих коэффициентов корреляции. Для каких генов корреляция самая высокая, а для каких — самая низкая? Как вы можете это объяснить?

# %%
ggplot(cors, aes(x = cc)) +
geom_histogram(aes(y =..density..), position = "identity", alpha = 0.5, bins = 50, 
               fill = 'lightgray', color = 'darkgray') + geom_density(alpha = 0.6) +
labs(title = 'correlation coefficients distribution', x = 'corrrelation', y = 'density') + 
theme_minimal() + theme(plot.title = element_text(size = 21, hjust = 0.5))
# Out:
# plot without title

# %%
ordered_cors <- cors %>% arrange(desc(abs(cc)))

# %%
print('гены с самой высокой корреляцией: ')
print(ordered_cors[1:10,])

print('гены с самой низкой корреляцией: ')
print(ordered_cors[(nrow(ordered_cors) - 10):nrow(ordered_cors),])
# Out:
# [1] "гены с самой высокой корреляцией: "
#                    cc geneSymbol
# ENSG00000124935.3   1    SCGB1D2
# ENSG00000176746.6   1     MAGEB6
# ENSG00000223614.5   1     ZNF735
# ENSG00000251258.1   1     RFPL4B
# ENSG00000143105.6   1     KCNA10
# ENSG00000156575.2   1       PRG3
# ENSG00000174016.11  1     FAM46D
# ENSG00000176040.13  1    TMPRSS7
# ENSG00000176979.12  1     TRIM60
# ENSG00000178690.2   1      DYNAP
# [1] "гены с самой низкой корреляцией: "
#                               cc geneSymbol
# ENSG00000081138.13 -0.0007709983       CDH7
# ENSG00000101306.10 -0.0007709983      MYLK2
# ENSG00000112309.10 -0.0007709983     B3GAT2
# ENSG00000119630.13 -0.0007619725        PGF
# ENSG00000196689.11  0.0007547224      TRPV1
# ENSG00000109063.14  0.0000000000       MYH3
# ENSG00000130749.9   0.0000000000      ZC3H4
# ENSG00000134830.5   0.0000000000      C5AR2
# ENSG00000141084.10  0.0000000000    RANBP10
# ENSG00000187987.9   0.0000000000    ZSCAN23
# ENSG00000277399.4   0.0000000000     GPR179

# %% [markdown]
# ##### Посмотрим summary для генов с высокой корреляцией. Как видно, некоторые из них действительно ассоциированы с раком
#
# | geneSymbol | genecards comment |
# | --- | --- |
# | SCGB1D2 | Secretoglobin Family. Diseases associated with SCGB1D2 include Breast Cancer and Prostate Cancer. |
# | MAGEB6 | Cancer/Testis Antigen Family. Melanoma-Associated Antigen. |
# | ZNF735 | Zinc Finger Protein. Mammalian transcriptional repressor. |
# | RFPL4B | Ret Finger Protein. Diseases associated with RFPL4B include Chromosome 15Q13.3 Deletion Syndrome |
# | KCNA10 | Potassium Voltage-Gated Channel Subfamily. Diseases associated with KCNA10 include Epileptic Encephalopathy, Early Infantile, and Alzheimer Disease. |
# | PRG3 | Proteoglycan. Among its related pathways are Innate Immune System. GO annotations related to this gene include carbohydrate binding. |
# | FAM46D | Terminal Nucleotidyltransferase. Antibodies against the protein encoded by this gene were found only in plasma from cancer patients. |
# | TMPRSS7 | Transmembrane Serine Protease. |
# | TRIM60 | Tripartite Motif Containing. Diseases associated with TRIM60 include Hypotrichosis-Lymphedema-Telangiectasia-Renal Defect Syndrome. |
# | DYNAP | Dynactin Associated Protein. Plays a role in the regulation of cell proliferation. |
#
# ##### Посмотрим summary для генов с низкой корреляцией. Здесь сложно сказать о каком-либо тренде.
#
# | geneSymbol | genecards comment |
# | --- | --- |
# | CDH7 | Cadherin 7. Diseases associated with CDH7 include Waardenburg Syndrome, Type 2D and Craniofacial-Deafness-Hand Syndrome. |
# | MYLK2 | Myosin Light Chain Kinase 2. Diseases associated with MYLK2 include Cardiomyopathy, Familial Hypertrophic, 1 and Hypertrophic Cardiomyopathy. |
# | B3GAT2 | Beta-1,3-Glucuronyltransferase. Diseases associated with B3GAT2 include Borna Disease. |
# | PGF | Placental Growth Factor. Diseases associated with PGF include Placental Insufficiency and Twin-To-Twin Transfusion Syndrome. |
# | TRPV1 | Transient Receptor Potential Cation Channel Subfamily V Member 1. Diseases associated with TRPV1 include Somatoform Disorder and Burning Mouth Syndrome. |
# | MYH3 | Myosin Heavy Chain 3. Diseases associated with MYH3 include Arthrogryposis, Distal, Type 2A and Contractures, Pterygia, And Spondylocarpotarsal Fusion Syndrome 1A. |
# | ZC3H4 | Zinc Finger CCCH-Type Containing 4. |
# | C5AR2 | Complement Component 5a Receptor 2. Diseases associated with C5AR2 include Complement Component 5 Deficiency and Complement Component 3 Deficiency.  |
# | RANBP10 | RAN Binding Protein 10. Diseases associated with RANBP10 include Penicilliosis and Lissencephaly. |
# | ZSCAN23 | Zinc Finger And SCAN Domain Containing 23. GO annotations related to this gene include DNA-binding transcription factor activity. |
#
# ##### Посмотрим как коррелируют значения между rnaseq и riboseq для отдельных генов  на графиках (сначала высокую корреляцию, затем низкую)

# %%
par(mfrow = c(3, 3))

scatter_for_gene <- function(x) {
    vals <- data.frame(cbind(rna = unlist(data[data$geneSymbol == x, colnames(expr_RNA)]),
                             rpf = unlist(data[data$geneSymbol == x, colnames(expr_RPF)]),
                             typ = rep(c('norm', 'tumor'), 10)))
    vals$typ <- as.factor(vals$typ)
    
    plot(vals$rna, vals$rpf, col = alpha(rep(c('green', 'red'), 10), 0.6), cex = 1.5, 
         xlab = 'RNA-Seq', ylab = 'Ribo-Seq', pch = 19, main = x)
    # abline(lm(vals$rpf ~ vals$rna), col="gray")
#ggplot(vals, aes(x = rna, y = rpf, shape = typ, color = typ)) +
#  geom_point(size = 5, alpha = .5) + ggtitle(x) +  theme(plot.title = element_text(hjust = 0.5))
}

for (x in c('SCGB1D2', 'MAGEB6', 'ZNF735', 'RFPL4B', 'KCNA10', 'PRG3', 'FAM46D', 'TMPRSS7', 'TRIM60')) {
  scatter_for_gene(x)
}
# Out:
# Plot with title “TRIM60”

# %%
par(mfrow = c(3, 3))
for (x in c('ZSCAN23', 'RANBP10', 'RANBP10', 'ZC3H4', 'MYH3', 'TRPV1', 'PGF', 'B3GAT2', 'MYLK2')) {
  scatter_for_gene(x)
}
# Out:
# Plot with title “MYLK2”

# %% [markdown]
# Для генов с высокой корреляцией, конечно, не очень много точек, но есть хорошее разделение на рак/норма.
#
# Для генов с низкой корреляцией такое разделение не наблюдается, но зато по ZSCAN23, MYH3, PGF, B3GAT2, MYLK2, что у нас больше ридов было получено в RNA-Seq.

# %% [markdown]
# 3. Найдите дифференциально экспрессированные гены по RNA-Seq между нормой и опухолью. Постройте volcano plot. То же самое сделайте и для Ribo-Seq эксперимента. Совпадают ли результаты дифференциальной экспрессии? Какие гены оказались значимо различны по экспрессии в одном случае, а какие — в другом? Выводы подкрепите графиками.

# %%
get_dif_expr <- function(df, ...) {
    splts <- strsplit(colnames(df), split = '.', fixed = TRUE)
    patients <- factor(t(data.frame(splts))[, 1])
    tissues <- factor(t(data.frame(splts))[, 2])
    
    design <- model.matrix(~ patients + tissues)
    rownames(design) <- colnames(df)
    
    df <- df %>% drop_na()
    y <- DGEList(genes = row.names(df), counts = df)
    y <- estimateDisp(y, design, robust = TRUE)

    lrt <- glmLRT(glmFit(y, design))
    print(summary(decideTests(lrt)))

    plotMD(lrt)
    abline(h = c(-1, 1), ...)

    return(list('y' = y, 'lrt' = lrt))
}

rna_output <- get_dif_expr(expr_RNA, col = 'pink', lwd = 2)
# Out:
#        tissuestumor
# Down           1645
# NotSig        14447
# Up             2853
# Plot with title “tissuestumor”

# %%
ggplot(data %>% drop_na(), 
       aes(x = rna_output[[2]]$table$logFC, y = -log10(rna_output[[2]]$table$PValue))) + 
geom_point(color = 'pink') +
labs(title = 'RNA-Seq volcano plot', x = '', y = '') + 
theme_minimal() + theme(plot.title = element_text(size = 21, hjust = 0.5))
# Out:
# plot without title

# %%
rpf_output <- get_dif_expr(expr_RPF, col = 'darkgreen', lwd = 2)
# Out:
#        tissuestumor
# Down            525
# NotSig        11192
# Up             7228
# Plot with title “tissuestumor”

# %%
ggplot(data, aes(x = rpf_output[[2]]$table$logFC, y = -log10(rpf_output[[2]]$table$PValue))) + 
geom_point(color = 'darkgreen') +
labs(title = 'Ribo-Seq volcano plot', x = '', y = '') + 
theme_minimal() + theme(plot.title = element_text(size = 21, hjust = 0.5))
# Out:
# plot without title

# %%
print(paste0('RNA common disp = ', rna_output[[1]]$common.dispersion, 
             '; RPF common disp = ', rpf_output[[1]]$common.dispersion))
# Out:
# [1] "RNA common disp = 0.241218172881907; RPF common disp = 0.245784421360873"

# %%
# наиболее дифференциально экспрессированные гены по RNA-Seq
toptags <- topTags(rna_output[[2]])$table[-1]
toptags['geneSymbol'] <- data$geneSymbol[data$geneID %in% rownames(toptags)]
toptags
# Out:
#                    logFC     logCPM   LR       PValue       FDR
# ENSG00000129965.13 -6.110186 6.697389 151.4819 8.223719e-35 1.557984e-30
# ENSG00000182566.12 -6.000234 5.300153 140.2753 2.317505e-32 2.195256e-28
# ENSG00000160339.15 -5.427818 5.016447 129.7281 4.699253e-30 2.967578e-26
# ENSG00000197408.8  -5.565073 8.641961 126.5603 2.318467e-29 1.098084e-25
# ENSG00000099769.5  -4.665919 6.300301 125.0711 4.910451e-29 1.860570e-25
# ENSG00000198077.10 -5.010297 5.335293 120.6405 4.580603e-28 1.446325e-24
# ENSG00000142748.12 -4.915110 6.080967 113.1640 1.986436e-26 5.376148e-23
# ENSG00000104938.16 -5.233403 4.195127 112.2597 3.134487e-26 7.422858e-23
# ENSG00000135423.12 -3.450832 6.426408 104.3122 1.728199e-24 3.637859e-21
# ENSG00000138315.12 -4.008663 5.450340 104.0575 1.965299e-24 3.723259e-21
#                    geneSymbol
# ENSG00000129965.13 IGFALS
# ENSG00000182566.12 CLEC4M
# ENSG00000160339.15 INS-IGF2
# ENSG00000197408.8  GLS2
# ENSG00000099769.5  OIT3
# ENSG00000198077.10 FCN3
# ENSG00000142748.12 FCN2
# ENSG00000104938.16 CLEC4G
# ENSG00000135423.12 CYP2B6
# ENSG00000138315.12 CYP2A7

# %%
cpm(rna_output[[1]])[order(rna_output[[2]]$table$PValue)[1:10],]
# Out:
#                    LC001.normal.RNA LC001.tumor.RNA LC033.normal.RNA
# ENSG00000145708.10 136.557347        31.862962      126.6377980
# ENSG00000134057.14   6.715935        93.030547       25.4537767
# ENSG00000135423.12 130.090150        17.908380       53.0111713
# ENSG00000139219.17   0.000000         0.000000        0.2103618
# ENSG00000110492.15  17.162945       143.499618       21.2465409
# ENSG00000214814.6    0.000000         1.628035        0.0000000
#                    LC507.tumor.RPF LC508.normal.RPF LC508.tumor.RPF
# ENSG00000112818.9    0.0000000       0.4100911      337.2298743
# ENSG00000163993.6    4.2682575       0.0000000        0.4340153
# ENSG00000107984.9    6.5279232       0.6151367       70.3104757
# ENSG00000112964.13   9.5408108     216.7331527       26.7642757
# ENSG00000145708.10   2.0085918     158.9103059        3.3274505
# ENSG00000134057.14 111.7279162       1.4353189      117.6181415
# ENSG00000135423.12   3.7661095      55.3623001        6.5102292
# ENSG00000139219.17   0.5021479       0.8201822      459.9115274
# ENSG00000110492.15  82.8544097       1.0252278      143.2250431
# ENSG00000214814.6    0.0000000       0.0000000       98.5214691
#                    LC509.normal.RPF LC509.tumor.RPF
# ENSG00000112818.9    1.3596264      516.80317
# ENSG00000163993.6    0.0000000        0.00000
# ENSG00000107984.9    0.3884647       69.30888
# ENSG00000112964.13 179.8591544       18.83393
# ENSG00000145708.10  93.6199918       17.70390
# ENSG00000134057.14   0.9711617       65.54209
# ENSG00000135423.12 131.4952997       27.30921
# ENSG00000139219.17   0.5826970      528.10353
# ENSG00000110492.15   2.1365558       26.55585
# ENSG00000214814.6    0.3884647       51.41664

# %%
rpf_significant_names <- row.names(rpf_output[[2]][rpf_output[[2]]$table$PValue < 0.01,])
length(rpf_significant_names)
# Out:
# [1] 6960

# %%
ggvenn(
  list(RNAseq = rna_significant_names, RiboSeq = rpf_significant_names),
       columns = c("RNAseq", "RiboSeq"),
  stroke_size = 0.5
)
# Out:
# plot without title

# %%
# 20 генов, значимых в обоих экспериментах
both_sig <-  Reduce(intersect, list(RNAseq = rna_significant_names, RiboSeq = rpf_significant_names))[1:20]
data.frame(cbind(ens_id = both_sig,
                 rpf_pval = rpf_output[[2]][both_sig, ]$table$PValue,
                 rna_pval = rna_output[[2]][both_sig, ]$table$PValue))
# Out:
#    ens_id             rpf_pval             rna_pval
# 1  ENSG00000000460.16 6.36854083891329e-08 0.00240397905212245
# 2  ENSG00000001036.13 2.14389366257816e-09 2.0706828603523e-05
# 3  ENSG00000001167.14 0.000140398689643054 5.14833927846242e-05
# 4  ENSG00000001561.6  0.00507935026035906  3.01949426657957e-06
# 5  ENSG00000001617.11 5.9542872610471e-05  0.00452810440967997
# 6  ENSG00000003989.16 5.79797824386328e-06 9.25014354787304e-06
# 7  ENSG00000004700.15 6.83525894555869e-06 3.586054097674e-06
# 8  ENSG00000004766.15 8.12469784471178e-06 0.000146035564034645
# 9  ENSG00000004897.11 5.19069691018205e-07 9.18377075439592e-05
# 10 ENSG00000005156.11 1.1305453055023e-07  0.0013529364967119
# 11 ENSG00000005175.9  0.00413738230222709  0.00128646771878929
# 12 ENSG00000005187.11 3.30058477503392e-05 9.94992496072569e-05
# 13 ENSG00000005421.8  1.80132365222335e-05 0.000259413473013672
# 14 ENSG00000005436.13 0.000412364071137743 0.00464302861675588
# 15 ENSG00000006007.11 0.000478523225840511 0.00011526259348239
# 16 ENSG00000006451.7  0.00251224298024687  0.000754420257255203
# 17 ENSG00000006453.13 0.000125955457787427 0.00784308416314612
# 18 ENSG00000006530.15 6.01282550822915e-05 0.0011923903572439
# 19 ENSG00000006625.17 0.00143336598784955  0.000567813041346506
# 20 ENSG00000006634.7  5.16580376078041e-05 0.00734475126405466

# %% [markdown]
# В целом, по графику видно, что дифференциаьно экспрессируемые гены между экспериментами не особо совпадают, а по таблице, что порядок p-value у значимых генов между экспериментами ощутимо различается. Наилучшим вариантом будет изучать гены на пересечении, оказавшиеся значимыми в обоих экспериментах, так как если рассматривать значимые изменения только по одному эксперименту, то это не всегда связано с реальными изменениями количества белка.

# %% [markdown]
# ##### Задание 2. Анализ wig-файла
# В папке курса на Google Drive хранятся два файла с .wig-трэками Ribo-Seq эксперимента кишечной палочки: ​02. RiboSeq_EColi_track_f.wig​и 0​ 2. RiboSeq_EColi_track_r.wig для прямой и обратной цепочек соответственно. Трэки эти были получены следующим образом: сначала прочтения прошли QC, адаптеры были удалены, а получившиеся “чистые” риды были откартированы на геном кишечной палочки. Затем каждой геномной позиции были присвоены значения, соответствующие числу 3’-концов прочтений, был определён оффсет для определения P-сайта, после чего скорректированные на этот оффсет значения и были записаны в wig-файл. Референсный геном, использовавшийся в ходе обработки прочтений, — U​ 00096.3.​Для выполнения заданий вам потребуется его аннотация (её вы можете найти в GenBank).

# %%
fw_track <- read.csv('/users/vraip/Anaconda/ngs/hw_riboseq/02. RiboSeq_EColi_track_f.wig', 
                     sep = '\t', skip = 1, header = FALSE, col.names = c('position', 'read_counts'))
rv_track <- read.csv('/users/vraip/Anaconda/ngs/hw_riboseq/02. RiboSeq_EColi_track_r.wig', 
                     sep = '\t', skip = 1, header = FALSE, col.names = c('position', 'read_counts'))

# %%
rec <- read.GenBank('U00096.3')
print(attr(rec, 'species'))
rec
# Out:
# [1] "Escherichia_coli_str._K-12_substr._MG1655"
# 1 DNA sequence in binary format stored in a list.
#
# Sequence length: 4641652
#
# Label:
# U00096.3
#
# Base composition:
#     a     c     g     t
# 0.246 0.254 0.254 0.246
# (Total: 4.64 Mb)

# %%
annotation <- read.gff('/users/vraip/Anaconda/ngs/hw_riboseq/sequence.gff3')
features <- annotation[annotation$type == 'CDS', ]
features$start <- as.numeric(features$start)
features$end <- as.numeric(features$end)
features <- features[ , !(names(features) == 'score')]
head(features)
# Out:
#    seqid    source  type start end  strand phase
# 3  U00096.3 Genbank CDS   190   255 +      0
# 5  U00096.3 Genbank CDS   337  2799 +      0
# 7  U00096.3 Genbank CDS  2801  3733 +      0
# 9  U00096.3 Genbank CDS  3734  5020 +      0
# 11 U00096.3 Genbank CDS  5234  5530 +      0
# 13 U00096.3 Genbank CDS  5683  6459 -      0
#    attributes
# 3  ID=cds-AAC73112.1;Parent=gene-b0001;Dbxref=UniProtKB/Swiss-Prot:P0AD86,NCBI_GP:AAC73112.1,ASAP:ABE-0000006,ECOCYC:EG11277;Name=AAC73112.1;gbkey=CDS;gene=thrL;locus_tag=b0001;product=thr operon leader peptide;protein_id=AAC73112.1;transl_table=11
# 5  ID=cds-AAC73113.1;Parent=gene-b0002;Dbxref=UniProtKB/Swiss-Prot:P00561,NCBI_GP:AAC73113.1,ASAP:ABE-0000008,ECOCYC:EG10998;Name=AAC73113.1;gbkey=CDS;gene=thrA;locus_tag=b0002;product=fused aspartate kinase/homoserine dehydrogenase 1;protein_id=AAC73113.1;transl_table=11
# 7  ID=cds-AAC73114.1;Parent=gene-b0003;Dbxref=UniProtKB/Swiss-Prot:P00547,NCBI_GP:AAC73114.1,ASAP:ABE-0000010,ECOCYC:EG10999;Name=AAC73114.1;gbkey=CDS;gene=thrB;locus_tag=b0003;product=homoserine kinase;protein_id=AAC73114.1;transl_table=11
# 9  ID=cds-AAC73115.1;Parent=gene-b0004;Dbxref=UniProtKB/Swiss-Prot:P00934,NCBI_GP:AAC73115.1,ASAP:ABE-0000012,ECOCYC:EG11000;Name=AAC73115.1;gbkey=CDS;gene=thrC;locus_tag=b0004;product=threonine synthase;protein_id=AAC73115.1;transl_table=11
# 11 ID=cds-AAC73116.1;Parent=gene-b0005;Dbxref=UniProtKB/Swiss-Prot:P75616,NCBI_GP:AAC73116.1,ASAP:ABE-0000015,ECOCYC:G6081;Name=AAC73116.1;gbkey=CDS;gene=yaaX;locus_tag=b0005;product=DUF2502 domain-containing protein YaaX;protein_id=AAC73116.1;transl_table=11
# 13 ID=cds-AAC73117.1;Parent=gene-b0006;Dbxref=UniProtKB/Swiss-Prot:P0A8I3,NCBI_GP:AAC73117.1,ASAP:ABE-0000018,ECOCYC:EG10011;Name=AAC73117.1;gbkey=CDS;gene=yaaA;locus_tag=b0006;product=peroxide stress resistance protein YaaA;protein_id=AAC73117.1;transl_table=11

# %% [markdown]
# 1. Присутствует ли в покрытии генома неравномерность? Рассмотрите неравномерность покрытия на примере любого выбранного вами гена. Что вы можете сказать про эту неравномерность? Присутствует ли там периодичность в три нуклеотида? А если взять среднее по большому количеству генов (взяв за точку отсчёта старт-кодон)? Выводы проиллюстрируйте графиками.

# %%
img <- readPNG('/users/vraip/Anaconda/ngs/hw_riboseq/pic1.PNG')
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG('/users/vraip/Anaconda/ngs/hw_riboseq/pic2.PNG')
grid::grid.raster(img)
# Out:
# plot without title

# %%
my_gene <- features[which(grepl('recN', features$attributes, fixed = TRUE)), ]
my_gene_cov <- fw_track[fw_track$position > my_gene$start & fw_track$position < my_gene$end, ]
barplot(my_gene_cov$read_counts[1:120])
# Out:
# plot without title

# %%
n <- 120
gene_counts <- c()
pos_counts <- t(apply(features, 1, function(x) {
    counts <- if (x["strand"] == 2) fw_track else rv_track    
    counts <- counts[counts$position >= as.numeric(x["start"]) & counts$position <= (as.numeric(x["start"]) + n), ]
    pos_counts <- c()
    for (i in seq(from = x["start"], by = 1, length.out = n)) {
        if (nrow(counts[as.numeric(counts$position) == i,]) > 0) {
            pos_counts <- c(pos_counts, as.numeric(counts[as.numeric(counts$position) == i,]$read_counts))
        } else {
            pos_counts <- c(pos_counts, 0)
        }
    }
    return(pos_counts)
}))
barplot(apply(pos_counts, 2, mean), col = c('pink', 'pink', 'lightblue'))
# Out:
# plot without title

# %% [markdown]
# ##### выводы
# на графике для одного гена покрытие неравномерное, и нельзя заметить периодичность в 3 нуклеотида, на агрегированном графике, где было рассчитано среднее по всем генам, в принципе можно говорить о наличии периодичности, но все равно какой-то не очень хороший график получился, потому что как минимум самый больший пик вроде должен ожидаться на первом кодоне, а по графику выходит, что он на втором. ВОзможо, какая-то ерунда с координатами в wig-файле.

# %% [markdown]
# 2. Рассчитайте значения RPKM и TPM для каждого гена. В чём разница между RPKM и TPM? Для чего используется каждая метрика?

# %% [markdown]
# ##### RPKM (Reads Per Kilobase Million)
#
# $RPKM = \frac{reads_{gene}}{len_{gene}*\sum{reads_{gene}}}*10^9$
#
#
# ##### TPM (Transcripts Per Kilobase Million)
#
# $TPM = \frac{reads_{gene} / len_{gene}}{\sum{reads_{gene}/len_{gene}}}*10^6$,
#
#
#
# То есть, единственное различие при вычислении TPM состоит в том, что сначала нормализуется длина гена, а затем глубина секвенирования. Однако это упрощает сравнение доли считываний, сопоставленных с геном в каждом образце.
#
# Тем не менее, обе метрики используются для нормализации глубины секвенирования и длины гена.

# %%
gene_counts <- apply(features, 1, function(x) {
  id <- strsplit(strsplit(x["attributes"], ';')[[1]][1], '=')[[1]][2]
  counts <- if (x["strand"] == 2) fw_track else rv_track
  return(id = sum(counts[counts$position >= as.numeric(x["start"]) & counts$position <= as.numeric(x["end"]), ]$read_counts))  
})

lib_size <- sum(gene_counts)

rpkm <- sapply(row.names(features), function(x) {
  len <- as.numeric(features[x,]$end) - as.numeric(features[x,]$start) + 1
  return(as.numeric(gene_counts[x]) * 10**9 / (lib_size * len))
})

tpm <- sapply(row.names(features), function(x) {
  len <- as.numeric(features[x,]$end) - as.numeric(features[x,]$start) + 1
  return(as.numeric(gene_counts[x]) * 10**6 / len)
})

k <- 1 / sum(tpm)
tpm <- tpm * k

# %% [markdown]
# 3. Проанализируйте значения RPKM для генов из оперона ATP. Укажите геномные координаты оперона, а также то, какие гены в него входят. Есть ли разница между RPKM у различных генов, присутствующих в опероне? Как вы можете объяснить эту разницу с биологической точки зрения? Как вы думаете, можно ли оценить эту разницу при помощи классического RNA-Seq?

# %%
atp <- features[which(grepl('atp', features$attributes, fixed = TRUE)), c(8, 4, 5, 6)]
atp['name'] <- sapply(atp$attributes, function(x) {
  strsplit(strsplit(x, ';')[[1]][4], '=')[[1]][2]
})
atp['gene'] <- sapply(atp$attributes, function(x) {
  strsplit(strsplit(x, ';')[[1]][6], '=')[[1]][2]
})
atp['product'] <- sapply(atp$attributes, function(x) {
  strsplit(strsplit(x, ';')[[1]][8], '=')[[1]][2]
})
atp[, 2:7]
# Out:
#      start   end     strand name       gene
# 7992 3915553 3915972 -      AAC76754.1 atpC
# 7994 3915993 3917375 -      AAC76755.1 atpD
# 7996 3917402 3918265 -      AAC76756.1 atpG
# 7998 3918316 3919857 -      AAC76757.1 atpA
# 8000 3919870 3920403 -      AAC76758.1 atpH
# 8002 3920418 3920888 -      AAC76759.1 atpF
# 8004 3920950 3921189 -      AAC76760.1 atpE
# 8006 3921236 3922051 -      AAC76761.1 atpB
# 8008 3922060 3922440 -      AAC76762.2 atpI
#      product
# 7992 ATP synthase F1 complex subunit epsilon
# 7994 ATP synthase F1 complex subunit beta
# 7996 ATP synthase F1 complex subunit gamma
# 7998 ATP synthase F1 complex subunit alpha
# 8000 ATP synthase F1 complex subunit delta
# 8002 ATP synthase Fo complex subunit b
# 8004 ATP synthase Fo complex subunit c
# 8006 ATP synthase Fo complex subunit a
# 8008 ATP synthase accessory factor AtpI

# %% [markdown]
# ##### Посмотрим на этот оперон в IGV. Его координаты 3915552:3922440

# %%
img <- readPNG('/users/vraip/Anaconda/ngs/hw_riboseq/pic3.PNG')
grid::grid.raster(img)
# Out:
# plot without title

# %%
sapply(row.names(atp), function(x) {
    print(paste0(atp[x,]$gene, '  :  ',rpkm[x]))
})
# Out:
# [1] "atpC  :  2120.2874778548"
# [1] "atpD  :  4681.22117104839"
# [1] "atpG  :  1123.59326230441"
# [1] "atpA  :  3649.71280070013"
# [1] "atpH  :  1360.39914765828"
# [1] "atpF  :  2063.89131619957"
# [1] "atpE  :  22892.1238627238"
# [1] "atpB  :  2159.07204145182"
# [1] "atpI  :  103.21231955884"
#                        7992                        7994
#  "atpC  :  2120.2874778548" "atpD  :  4681.22117104839"
#                        7996                        7998
# "atpG  :  1123.59326230441" "atpA  :  3649.71280070013"
#                        8000                        8002
# "atpH  :  1360.39914765828" "atpF  :  2063.89131619957"
#                        8004                        8006
# "atpE  :  22892.1238627238" "atpB  :  2159.07204145182"
#                        8008
#  "atpI  :  103.21231955884"

# %% [markdown]
# Разница между генами в опероне определенно есть. ВОзможно, это связано с размером или количеством субъединиц. На рисунке ниже видно, что нужно 10 субъединиц atpE, неудивительно, что именно для него самое высокое значение RPKM.
#
#
# Не думаю, что эту разницу можно было бы увидеть на данных RNA-seq, так как у прокариот гены объединены в опероны, а RNA-seq у прокариот считываает транскрипты, так что весь оперон считался бы как один транскрипт. А после нормализации число прочтений во всех генах оперона было бы более или менее одинаковым.

# %%
img <- readPNG('/users/vraip/Anaconda/ngs/hw_riboseq/pic4.PNG')
grid::grid.raster(img)
# Out:
# plot without title
